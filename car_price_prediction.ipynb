# %% [markdown]
# <a href="https://colab.research.google.com/github/bt-ktm/car_price_prediction/blob/main/car_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
os.getcwd()
# Out:
# '/content'

# %%
df = pd.read_csv("car_prediction.csv")
